# %% [markdown]
# <a href="https://colab.research.google.com/github/SKashhh/Voyage-AI-Traveller-Segmentation/blob/main/notebook/VOYAGE_AI_TRAVELLER_SEGMENTATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Voyage AI – Traveller Segmentation

#This notebook implements an unsupervised machine learning approach to segment travellers based on their travel behaviour.

# %%
print("Notebook is working correctly")
# Out:
# Notebook is working correctly
